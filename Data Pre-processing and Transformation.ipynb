# %%
print('Hy')
# Out:
# Hy

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/TRYMORE/Desktop/DataSets/creditdata.csv")
df.columns
# Out:
# Index(['Customer_ID', 'Gender', 'Age', 'Marital_Status', 'Employment_Status',
#        'Level_of_Education', 'Residence_Area', 'Home_Ownership',
#        'Number_of_Dependants', 'Product_Quantity', 'Total_Amount',
#        'Other_Solar_Product_purchase_on_installments', 'Tenure',
#        'DefaultStatus'],
#       dtype='object')

# %%
#Separate continuos columns
num_cols = df.select_dtypes(include = ['number']).columns
num_cols
# Out:
# Index(['Age', 'Number_of_Dependants', 'Product_Quantity', 'Total_Amount',
#        'DefaultStatus'],
#       dtype='object')

# %%
#Select categorical colums
cat_cols = df.select_dtypes(include = ['object', 'category']).columns
cat_cols
# Out:
# Index(['Customer_ID', 'Gender', 'Marital_Status', 'Employment_Status',
#        'Level_of_Education', 'Residence_Area', 'Home_Ownership',
#        'Other_Solar_Product_purchase_on_installments', 'Tenure'],
#       dtype='object')

# %%
#Fill missing values for numerical variables
df[num_cols] = df[num_cols].fillna(df[num_cols].mean())

# %%
#Fill missing values for categorical variables
df[cat_cols] = df[cat_cols].fillna(df[cat_cols].mode())

# %%
#Fix data types once 
df = df.convert_dtypes()

# %%
#Drop column Customer ID since its not a variable
df.drop(columns = ['Customer_ID'],inplace = True)

# %%
#Label encording ordinal variables

from sklearn.preprocessing import LabelEncoder as ln
df['Level_of_Education'] = ln().fit_transform(df['Level_of_Education'])
df['Residence_Area'] = ln().fit_transform(df['Residence_Area'])
df['Tenure'] = ln().fit_transform(df['Tenure'])

# %%
cat_cols
# Out:
# Index(['Customer_ID', 'Gender', 'Marital_Status', 'Employment_Status',
#        'Level_of_Education', 'Residence_Area', 'Home_Ownership',
#        'Other_Solar_Product_purchase_on_installments', 'Tenure'],
#       dtype='object')

# %%
#Norminal  variables Target encoding
import category_encoders as ce

# %%
#List the norminal variables
nominal_vars = ['Gender', 'Marital_Status', 'Employment_Status','Home_Ownership','Other_Solar_Product_purchase_on_installments']

# %%
#Initialize the encoder
target_encoder = ce.TargetEncoder(cols=nominal_vars)

# %%
#Fit and transform the data
df[nominal_vars] = target_encoder.fit_transform(df[nominal_vars], df['DefaultStatus'])

# %%
#Feature Scaling (I am using Standadization)
from sklearn.preprocessing import StandardScaler as std

# %%
#Define the continuous variables
num_vars = ['Age', 'Number_of_Dependants', 'Product_Quantity', 'Total_Amount']

# %%
#Transform using standardization
scaler = std()
df[num_vars] = scaler.fit_transform(df[num_vars])

# %%
#Use Quantile transformer
#from sklearn.preprocessing import QuantileTransformer as qt

#scaler = qt(n_quantiles=100)
#df[num_vars] = scaler.fit_transform(df[num_vars])

# %%
#Split the dataset
from sklearn.model_selection import train_test_split as tts
x = df.drop('DefaultStatus', axis = 1)
y = df['DefaultStatus']

# %%
y
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 306    1
# 307    0
# 308    1
# 309    0
# 310    1
# Name: DefaultStatus, Length: 311, dtype: Int64

# %%
#Now split into train and test set
x_train, x_test, y_train, y_test = tts(x, y, test_size = 0.3, random_state = 42)

# %%
#Create A Model (DECISION TREE)
from sklearn.tree import DecisionTreeClassifier as dt

model = dt()

# %%
#Train the created model to learn the patterns in the data
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Make predictions
predictions = model.predict(x_test)

# %%
#Perfomance metrics , model evaluation
from sklearn.metrics import accuracy_score as acs

# %%
#Check accuracy
score = acs(y_test, predictions)

# %%
score
# Out:
# 0.8191489361702128

# %%
#Model Persistence
#from sklearn.externals import joblib

# %%
#joblib.dump(model, 'DecisionTree.joblib')

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Marital_Status', 'Employment_Status',
#        'Level_of_Education', 'Residence_Area', 'Home_Ownership',
#        'Number_of_Dependants', 'Product_Quantity', 'Total_Amount',
#        'Other_Solar_Product_purchase_on_installments', 'Tenure',
#        'DefaultStatus'],
#       dtype='object')

# %%
#Disply the decision tree
from sklearn import tree
tree.export_graphviz(model, out_file='DecisionTree.dot',
                     feature_names=['Gender', 'Age', 'Marital_Status', 'Employment_Status', 'Level_of_Education'],
                     class_names = sorted(y.unique()),
                                          label = 'all',
                                          rounded = True,
                                          filled = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 3
#       1 #Disply the decision tree
#       2 from sklearn import tree
# ----> 3 tree.export_graphviz(model, out_file='DecisionTree.dot',
#       4                      feature_names=['Gender', 'Age', 'Marital_Status', 'Employment_Status', 'Level_of_Education'],
#       5                      class_names = sorted(y.unique()),
#       6                                           label = 'all',
#       7                                           rounded = True,
#       8                                           filled = True)
#
# File c:\Users\TRYMORE\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\TRYMORE\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\tree\_export.py:938, in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     919     out_file = StringIO()
#     921 exporter = _DOTTreeExporter(
#     922     out_file=out_file,
#     923     max_depth=max_depth,
#    (...)    936     fontname=fontname,
#     937 )
# --> 938 exporter.export(decision_tree)
#     940 if return_string:
#     941     return exporter.out_file.getvalue()
#
# File c:\Users\TRYMORE\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\tree\_export.py:460, in _DOTTreeExporter.export(self, decision_tree)
#     458 if self.feature_names is not None:
#     459     if len(self.feature_names) != decision_tree.n_features_in_:
# --> 460         raise ValueError(
#     461             "Length of feature_names, %d does not match number of features, %d"
#     462             % (len(self.feature_names), decision_tree.n_features_in_)
#     463         )
#     464 # each part writes to out_file
#     465 self.head()
#
# ValueError: Length of feature_names, 5 does not match number of features, 12

# %%
#LOGISTIC REGRESSION

#Logistic Regression
from sklearn.linear_model import LogisticRegression as lg
from sklearn.model_selection import train_test_split as tts
x = df.drop('DefaultStatus', axis = 1)
y = df['DefaultStatus']
x_train, x_test, y_train, y_test = tts(x, y, test_size = 0.3, random_state = 42)
model = lg(class_weight={0:1, 1:2}, max_iter=1000)
model.fit( x_train, y_train)
# Out:
# LogisticRegression(class_weight={0: 1, 1: 2}, max_iter=1000)

# %%
#Make predictions
predictions = model.predict(x_test)
from sklearn.metrics import accuracy_score as acs
score = acs(y_test, predictions)
score
# Out:
# 0.925531914893617
